# %%
import sys
from pathlib import Path

# Make sure Python can see the ai folder
AI_DIR = Path.cwd().parent
sys.path.insert(0, str(AI_DIR))

from pipeline import run_ai_pipeline

print("Pipeline imported successfully!")
# Out:
# Pipeline imported successfully!

# %% [markdown]
# Create a test machine

# %%
test_machine = {
    "Air temperature [K]": 298.7,
    "Process temperature [K]": 310.1,
    "Rotational speed [rpm]": 1402.0,
    "Torque [Nm]": 69.7,
    "Tool wear [min]": 64.0,
    "Type": "L"
}

# %%
result = run_ai_pipeline(test_machine)

result
# Out:
# {'failure_prediction': {'failure_probability': 0.9986,
#   'failure_probability_percent': 99.86,
#   'risk_level': 'CRITICAL'},
#  'anomaly_detection': {'anomaly_detected': False}}

# %%
import sys
from pathlib import Path

AI_DIR = Path.cwd().parent

if str(AI_DIR) not in sys.path:
    sys.path.insert(0, str(AI_DIR))

# %%
from pipeline import run_ai_pipeline

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# C:\Users\LENOVO\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe
# 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
